# %% [markdown]
# <a href="https://colab.research.google.com/github/ss8319/SMPL_Neural_Avatar/blob/main/colab_notebooks/SMPLpix_stable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](https://user-images.githubusercontent.com/8117267/116876711-8defc300-ac25-11eb-8b7b-5eab8860602c.png)
#
# # SMPLpix Dataset Preparation.
#
# **Author**: [Sergey Prokudin](https://ps.is.mpg.de/people/sprokudin).
# [[Project Page](https://sergeyprokudin.github.io/smplpix/)]
# [[Paper](https://arxiv.org/pdf/2008.06872.pdf)]
# [[Video](https://www.youtube.com/watch?v=JY9t4xUAouk)]
# [[GitHub](https://github.com/sergeyprokudin/smplpix)]
#
# This notebook contains an example workflow for converting a video file to a SMPLpix dataset.
# ### Processing steps:
#
# 1. Download the video of choice, extract frames;
# 2. Extract **2D keypoints**: run [OpenPose](https://github.com/CMU-Perceptual-Computing-Lab/openpose) on the extracted frames;
# 3. Infer **3D human meshes**: run [SMPLify-x](https://github.com/vchoutas/smplify-x) on the extracted frames + keypoints;
# 4. Form dataset **image pairs**, where *input* is SMPL-X mesh render, and *output* is the corresponding target ground truth video frame;
# 5. **Split the data** into train, test and validation, zip and copy to Google Drive.
#
# ### Instructions
#
# 1. Convert a video into our dataset format using this notebook.
# 2. Train a SMPLpix using the training notebook.
#
#
# ### Notes
# * While this will work for small datasets in a Colab runtime, larger datasets will require more compute power;
# * If you would like to train a model on a serious dataset, you should consider copying this to your own workstation and running it there. Some minor modifications will be required, and you will have to install the dependencies separately;
# * Please report issues on the [GitHub issue tracker](https://github.com/sergeyprokudin/smplpix/issues).
#
# If you find this work useful, please consider citing:
# ```bibtex
# @inproceedings{prokudin2021smplpix,
#   title={SMPLpix: Neural Avatars from 3D Human Models},
#   author={Prokudin, Sergey and Black, Michael J and Romero, Javier},
#   booktitle={Proceedings of the IEEE/CVF Winter Conference on Applications of Computer Vision},
#   pages={1810--1819},
#   year={2021}
# }
# ```
#
# Many thanks [Keunhong Park](https://keunhong.com) for providing the [Nerfie dataset preparation template](https://colab.research.google.com/github/google/nerfies/blob/main/notebooks/Nerfies_Capture_Processing.ipynb)!

# %% [markdown]
# ## Upload the video and extract frames

# %%
# @title Upload a video file (.mp4, .mov, etc.) from your disk, Dropbox, Google Drive or YouTube

# @markdown  This will upload it to the local Colab working directory. You can use a demo video to test the pipeline. The background in the demo was removed with the [Unscreen](https://www.unscreen.com/) service. Alternatively, you can try [PointRend](https://github.com/facebookresearch/detectron2/tree/master/projects/PointRend) segmentation for this purpose. 

import os
from google.colab import files

def download_youtube_video(img_url, save_path, resolution_id=-3):

  print("downloading the video: %s" % img_url)
  res_path = YouTube(img_url).streams.order_by('resolution')[resolution_id].download(save_path)

  return res_path

def download_dropbox_url(url, filepath, chunk_size=1024):

    import requests
    headers = {'user-agent': 'Wget/1.16 (linux-gnu)'}
    r = requests.get(url, stream=True, headers=headers)
    with open(filepath, 'wb') as f:
        for chunk in r.iter_content(chunk_size=chunk_size):
            if chunk:
                f.write(chunk)
    return filepath

# !rm -rf /content/data

from google.colab import drive
drive.mount('/content/gdrive')

VIDEO_SOURCE = 'google drive' #@param ["youtube", "upload", "google drive", "dropbox"]

if VIDEO_SOURCE == 'dropbox':
  DROPBOX_URL  = 'https://www.dropbox.com/s/rjqwf894ovso218/smplpix_test_video_na.mp4?dl=0' #@param 
  VIDEO_PATH  = '/content/video.mp4' 
  download_dropbox_url(DROPBOX_URL, VIDEO_PATH)
elif VIDEO_SOURCE == 'upload':
  print("Please upload the video: ")
  uploaded = files.upload()
  VIDEO_PATH = os.path.join('/content', list(uploaded.keys())[0])
elif VIDEO_SOURCE == 'youtube':
  # !pip install pytube
  from pytube import YouTube
  YOTUBE_VIDEO_URL  = ''  #@param 
  VIDEO_PATH = download_youtube_video(YOTUBE_VIDEO_URL, '/content/')
elif VIDEO_SOURCE == 'google drive':
  from google.colab import drive
  drive.mount('/content/gdrive')
  GOOGLE_DRIVE_PATH = '/content/gdrive/MyDrive/Signapse and SIL/Salvadorian_1_Trim.mp4' #@param 
  VIDEO_PATH  = GOOGLE_DRIVE_PATH


print("video is uploaded to %s" % VIDEO_PATH)
# Out:
# Mounted at /content/gdrive
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# video is uploaded to /content/gdrive/MyDrive/Signapse and SIL/Salvadorian_1_Trim.mp4

# %%
# @title Flatten the video into frames


FPS =     60# @param {type:'number'}

# @markdown _Note_: for longer videos, it might make sense to decrease the FPS as it will take 30-60 seconds for SMPLify-X framework to process every frame.



RES_DIR = '/content/data'
FRAMES_DIR = os.path.join(RES_DIR, 'images')
# !rm -rf $RES_DIR
# !mkdir $RES_DIR
# !mkdir $FRAMES_DIR
#!ffmpeg -i "$VIDEO_PATH" -vf fps=$FPS  -qscale:v 2 '$FRAMES_DIR/%05d.png'
# !ffmpeg -i "$VIDEO_PATH" -vf fps=$FPS  -qscale:v 2 '/content/data/images/%05d.png'
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

def load_img(img_path):

  return np.asarray(Image.open(img_path))/255

test_img_path = os.path.join(FRAMES_DIR, os.listdir(FRAMES_DIR)[0])

test_img = load_img(test_img_path)

plt.figure(figsize=(5, 10))
plt.title("extracted image example")
plt.imshow(test_img)
# Out:
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/gdrive/MyDrive/Signapse and SIL/Salvadorian_1_Trim.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp41isom
#     creation_time   : 2021-08-25T23:28:15.000000Z
#   Duration: 00:00:10.26, start: 0.000000, bitrate: 3132 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], 3019 kb/s, 30 fps, 30 tbr, 30k tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-23T03:26:53.000000Z
#       handler_name    : VideoHandler
#       encoder         : AVC Coding
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 117 kb/s (default)
#     Metadata:
#       creation_time   : 2022-11-23T03:26:53.000000Z
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/content/data/images/%05d.png':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp41isom
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: png, rgb24, 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 60 fps, 60 tbn, 60 tbc (default)
#     Metadata:
#       creation_time   : 2022-11-23T03:26:53.000000Z
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 png
# frame=  614 fps= 76 q=-0.0 Lsize=N/A time=00:00:10.23 bitrate=N/A speed=1.27x
# video:427744kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %% [markdown]
# ## Extract 2D body keypoints with OpenPose

# %%
# @title Install OpenPose
# @markdown This will take some time (~10 mins). The code is taken from this [OpenPose Colab notebook](https://colab.research.google.com/github/tugstugi/dl-colab-notebooks/blob/master/notebooks/OpenPose.ipynb).

# %cd /content
import os
from os.path import exists, join, basename, splitext

git_repo_url = 'https://github.com/CMU-Perceptual-Computing-Lab/openpose.git'
project_name = splitext(basename(git_repo_url))[0]
if not exists(project_name):
  # see: https://github.com/CMU-Perceptual-Computing-Lab/openpose/issues/949
  # install new CMake becaue of CUDA10
  # !wget -q https://cmake.org/files/v3.13/cmake-3.13.0-Linux-x86_64.tar.gz
  # !tar xfz cmake-3.13.0-Linux-x86_64.tar.gz --strip-components=1 -C /usr/local

  # clone openpose
  # !git clone -q --depth 1 $git_repo_url
  # download models
  # !wget -O /content/openpose/models/hand/pose_iter_102000.caffemodel https://polybox.ethz.ch/index.php/s/Oim76cuqrDVbdxm/download
  # !wget -O /content/openpose/models/pose/body_25/pose_iter_584000.caffemodel https://polybox.ethz.ch/index.php/s/m5NQAhd7ukVPRoL/download
  # !wget -O /content/openpose/models/face/pose_iter_116000.caffemodel https://polybox.ethz.ch/index.php/s/cEaF1FTpKjjJZbH/download
  # !sed -i 's/execute_process(COMMAND git checkout master WORKING_DIRECTORY ${CMAKE_SOURCE_DIR}\/3rdparty\/caffe)/execute_process(COMMAND git checkout f019d0dfe86f49d1140961f8c7dec22130c83154 WORKING_DIRECTORY ${CMAKE_SOURCE_DIR}\/3rdparty\/caffe)/g' openpose/CMakeLists.txt
  # install system dependencies
  # !apt-get -qq install -y libatlas-base-dev libprotobuf-dev libleveldb-dev libsnappy-dev libhdf5-serial-dev protobuf-compiler libgflags-dev libgoogle-glog-dev liblmdb-dev opencl-headers ocl-icd-opencl-dev libviennacl-dev
  # install python dependencies
  # !pip install -q youtube-dl
  # build openpose
  # !cd openpose && rm -rf build || true && mkdir build && cd build && cmake .. && make -j`nproc`

# %%
# @title Run OpenPose on the extracted frames
# %cd /content
KEYPOINTS_DIR = os.path.join(RES_DIR, 'keypoints')
OPENPOSE_IMAGES_DIR = os.path.join(RES_DIR, 'openpose_images')
# !mkdir $KEYPOINTS_DIR
# !mkdir $OPENPOSE_IMAGES_DIR

# !cd openpose && ./build/examples/openpose/openpose.bin --image_dir $FRAMES_DIR --write_json $KEYPOINTS_DIR --face --hand --display 0   --write_images $OPENPOSE_IMAGES_DIR

input_img_path = os.path.join(FRAMES_DIR, sorted(os.listdir(FRAMES_DIR))[0])
openpose_img_path = os.path.join(OPENPOSE_IMAGES_DIR, sorted(os.listdir(OPENPOSE_IMAGES_DIR))[0])

test_img = load_img(input_img_path)
open_pose_img = load_img(openpose_img_path)

plt.figure(figsize=(10, 10))
plt.title("Input Frame + Openpose Prediction")
plt.imshow(np.concatenate([test_img, open_pose_img], 1))
# Out:
# /content
# Starting OpenPose demo...
# Configuring OpenPose...
# Starting thread(s)...
# Auto-detecting all available GPUs... Detected 1 GPU(s), using 1 of them starting at GPU 0.
# OpenPose demo successfully finished. Total time: 781.125894 seconds.

# %% [markdown]
# ## Infer 3D Human Model with [SMPLify-X](https://smpl-x.is.tue.mpg.de/)

# %%
#install python 3.8
# !sudo apt-get update -y
# !sudo apt-get install python3.8

#change alternatives
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.7 1
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 2

#check python version
# !python --version

#download pip
# !sudo apt-get install python3-pip

# %%
# !sudo apt-get install python3-pip._internal
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package python3-pip._internal
# E: Couldn't find any package by glob 'python3-pip._internal'
# E: Couldn't find any package by regex 'python3-pip._internal'

# %%
# @title Install SMPLify-X and other dependencies

# %cd /content
# !pip install chumpy
# !pip install smplx
# !git clone https://github.com/vchoutas/smplx
# %cd smplx
# !python setup.py install

#vposer
# !pip install git+https://github.com/nghorbani/configer
# !pip install git+https://github.com/sergeyprokudin/human_body_prior

# !pip install torch==1.1.0
# %cd /content
# !git clone https://github.com/sergeyprokudin/smplify-x
# %cd /content/smplify-x
# !pip install -r requirements.txt

# %%
# @title Upload the SMPL-X model files

# @markdown Proceed to the [official website](https://smpl-x.is.tue.mpg.de/), register and download the zip files with SMPL-X (**models_smplx_v1_1.zip**, ~830MB) and VPoser (**vposer_v1_0.zip**, ~2.5MB) models from the **Downloads** section. 
# @markdown

# @markdown Since uploading large zip files to Colab is relatively slow, we expect you to upload these files to Google Drive instead, link gdrive to the Colab file systems and modify **SMPLX_ZIP_PATH** and **VPOSER_ZIP_PATH** variables accordingly.

# %cd /content/
from google.colab import drive
drive.mount('/content/gdrive')

SMPLX_ZIP_PATH = '/content/gdrive/MyDrive/SMPL/models_smplx_v1_1.zip' # @param {type:"string"}
VPOSER_ZIP_PATH = '/content/gdrive/MyDrive/SMPL/vposer_v1_0.zip' # @param {type:"string"}

SMPLX_MODEL_PATH = '/content/smplx'
# !mkdir $SMPLX_MODEL_PATH
# !unzip -n '/content/gdrive/MyDrive/SMPL/models_smplx_v1_1.zip' -d  $SMPLX_MODEL_PATH
VPOSER_MODEL_PATH = '/content/vposer'
# !mkdir $VPOSER_MODEL_PATH
# !unzip -n '/content/gdrive/MyDrive/SMPL/vposer_v1_0.zip' -d  $VPOSER_MODEL_PATH
# Out:
# /content
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# mkdir: cannot create directory ‘/content/smplx’: File exists
# Archive:  /content/gdrive/MyDrive/SMPL/models_smplx_v1_1.zip
# mkdir: cannot create directory ‘/content/vposer’: File exists
# Archive:  /content/gdrive/MyDrive/SMPL/vposer_v1_0.zip

# %%
# @title Run SMPLify-X

# @markdown Please select gender of the SMPL-X model:

gender = 'male' #@param ["neutral", "female", "male"]

# @markdown Please keep in mind that estimating 3D body with SMPLify-X framework will take ~30-60 secs, so processing long videos at high FPS might take a long time.

# !rm -rf /content/data/smplifyx_results
# %cd /content/smplify-x
# !git pull origin
# !python smplifyx/main.py --config cfg_files/fit_smplx.yaml \
    --data_folder  /content/data \
    --output_folder /content/data/smplifyx_results \
    --visualize=True \
    --gender=$gender \
    --model_folder /content/smplx/models \
    --vposer_ckpt /content/vposer/vposer_v1_0 \
    --part_segm_fn smplx_parts_segm.pkl
# Out:
# /content/smplify-x
# Already up to date.
# Processing: /content/data/images/00001.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00002.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00003.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00004.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00005.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00006.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00007.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00008.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00009.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00010.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00011.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00012.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00013.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00014.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00015.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00016.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00017.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00018.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00019.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00020.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00021.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00022.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00023.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00024.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00025.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00026.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00027.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00028.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00029.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00030.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00031.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00032.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00033.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00034.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00035.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00036.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00037.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00038.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00039.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00040.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00041.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00042.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00043.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00044.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00045.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00046.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00047.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00048.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00049.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00050.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00051.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00052.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00053.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00054.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00055.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00056.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00057.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00058.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00059.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00060.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00061.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00062.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00063.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00064.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00065.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00066.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00067.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00068.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00069.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00070.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00071.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00072.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00073.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00074.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00075.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00076.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00077.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00078.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00079.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00080.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00081.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00082.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00083.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00084.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00085.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00086.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00087.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00088.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00089.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00090.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00091.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00092.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00093.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00094.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00095.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00096.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00097.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00098.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00099.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00100.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00101.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00102.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00103.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00104.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00105.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00106.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00107.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00108.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00109.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00110.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00111.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00112.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00113.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00114.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00115.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00116.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00117.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00118.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00119.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00120.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00121.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00122.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00123.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00124.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00125.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00126.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00127.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00128.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00129.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00130.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00131.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00132.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00133.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00134.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00135.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00136.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00137.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00138.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00139.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00140.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00141.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00142.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00143.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00144.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00145.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00146.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00147.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00148.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00149.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00150.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00151.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00152.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00153.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00154.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00155.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00156.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00157.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00158.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00159.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00160.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00161.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00162.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00163.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00164.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00165.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00166.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00167.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00168.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00169.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00170.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00171.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00172.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00173.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00174.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00175.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00176.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00177.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00178.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00179.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00180.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00181.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00182.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00183.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00184.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00185.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00186.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00187.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00188.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00189.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00190.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00191.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00192.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00193.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00194.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00195.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00196.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00197.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00198.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00199.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00200.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00201.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00202.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00203.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00204.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00205.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00206.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00207.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00208.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00209.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00210.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00211.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00212.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00213.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00214.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00215.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00216.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00217.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00218.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00219.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00220.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00221.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00222.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00223.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00224.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00225.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00226.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00227.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00228.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00229.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00230.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00231.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00232.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00233.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00234.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00235.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00236.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00237.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00238.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00239.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00240.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00241.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00242.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00243.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00244.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00245.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00246.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00247.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00248.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00249.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00250.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00251.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00252.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00253.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00254.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00255.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00256.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00257.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00258.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00259.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00260.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00261.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00262.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00263.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00264.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00265.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00266.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00267.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00268.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00269.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00270.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00271.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00272.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00273.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00274.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00275.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00276.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00277.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00278.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00279.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00280.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00281.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00282.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00283.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00284.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00285.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00286.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00287.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00288.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00289.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00290.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00291.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00292.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00293.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00294.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00295.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00296.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00297.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00298.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00299.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00300.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00301.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00302.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00303.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00304.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00305.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00306.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00307.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00308.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00309.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00310.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00311.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00312.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00313.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00314.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00315.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00316.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00317.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00318.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00319.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00320.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00321.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00322.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00323.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00324.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00325.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00326.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00327.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00328.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00329.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00330.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00331.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00332.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00333.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00334.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00335.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00336.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00337.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00338.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00339.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00340.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00341.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00342.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00343.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00344.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00345.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00346.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00347.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00348.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00349.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00350.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00351.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00352.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00353.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00354.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00355.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00356.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00357.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00358.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00359.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00360.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00361.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00362.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00363.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00364.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00365.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00366.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00367.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00368.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00369.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00370.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00371.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00372.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00373.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00374.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00375.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00376.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00377.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00378.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00379.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00380.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00381.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00382.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00383.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00384.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00385.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00386.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00387.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00388.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00389.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00390.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00391.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00392.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00393.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00394.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00395.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00396.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00397.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00398.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00399.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00400.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00401.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00402.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00403.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00404.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00405.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00406.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00407.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00408.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00409.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00410.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00411.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00412.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00413.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00414.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00415.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00416.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00417.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# ...
# Processing: /content/data/images/00477.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00478.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00479.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00480.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00481.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00482.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00483.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00484.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00485.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00486.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00487.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00488.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00489.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00490.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00491.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00492.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00493.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00494.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00495.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00496.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00497.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00498.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00499.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00500.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00501.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00502.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00503.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00504.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00505.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00506.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00507.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00508.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00509.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00510.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00511.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00512.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00513.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00514.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00515.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00516.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00517.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00518.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00519.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00520.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00521.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00522.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00523.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00524.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00525.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00526.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00527.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00528.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00529.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00530.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00531.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00532.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00533.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00534.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00535.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00536.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00537.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00538.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00539.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00540.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00541.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00542.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00543.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00544.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00545.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00546.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00547.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00548.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00549.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00550.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00551.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00552.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00553.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00554.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00555.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00556.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00557.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00558.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00559.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00560.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00561.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00562.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00563.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00564.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00565.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00566.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00567.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00568.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00569.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00570.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00571.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00572.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00573.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00574.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00575.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00576.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00577.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00578.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00579.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00580.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00581.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00582.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00583.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00584.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00585.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00586.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00587.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00588.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00589.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00590.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00591.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00592.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00593.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00594.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00595.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00596.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00597.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00598.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00599.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00600.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00601.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00602.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00603.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00604.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00605.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00606.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00607.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00608.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00609.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00610.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00611.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00612.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00613.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing: /content/data/images/00614.png
# Found Trained Model: /content/vposer/vposer_v1_0/snapshots/TR00_E096.pt
# Processing the data took: 00 hours, 00 minutes, 53 seconds

# %%
# @title Make train-test-validation splits, copy data to final folders

import shutil

train_ratio = 0.9 #@param
 
final_zip_path = '/content/gdrive/MyDrive/datasets/smplpix_data_test.zip' # @param {type:"string"}


target_images_path = '/content/data/smplifyx_results/input_images'
smplifyx_renders = '/content/data/smplifyx_results/rendered_smplifyx_meshes'

smplpix_data_path = '/content/smplpix_data'

train_input_dir = os.path.join(smplpix_data_path, 'train', 'input')
train_output_dir = os.path.join(smplpix_data_path, 'train', 'output')
val_input_dir = os.path.join(smplpix_data_path, 'validation', 'input')
val_output_dir = os.path.join(smplpix_data_path, 'validation', 'output')
test_input_dir = os.path.join(smplpix_data_path, 'test', 'input')
test_output_dir = os.path.join(smplpix_data_path, 'test', 'output')

# !mkdir -p $target_images_path
# !mkdir -p $final_zip_path
# !mkdir -p $train_input_dir
# !mkdir -p $train_output_dir
# !mkdir -p $val_input_dir
# !mkdir -p $val_output_dir
# !mkdir -p $test_input_dir
# !mkdir -p $test_output_dir

img_names = sorted(os.listdir(target_images_path))
n_images = len(img_names)
n_train_images = int(n_images * train_ratio)
n_val_images = int(n_images * (1-train_ratio) / 2)
train_images = img_names[0:n_train_images]
val_images = img_names[n_train_images:n_train_images+n_val_images]
test_images = img_names[n_train_images:]

for img in train_images:
  shutil.copy(os.path.join(smplifyx_renders, img), train_input_dir)
  shutil.copy(os.path.join(target_images_path, img), train_output_dir)

for img in val_images:
  shutil.copy(os.path.join(smplifyx_renders, img), val_input_dir)
  shutil.copy(os.path.join(target_images_path, img), val_output_dir)

for img in test_images:
  shutil.copy(os.path.join(smplifyx_renders, img), test_input_dir)
  shutil.copy(os.path.join(target_images_path, img), test_output_dir)


# %cd /content
# !zip -r $final_zip_path smplpix_data/
# Out:
# /content
# 	zip warning: missing end signature--probably not a zip file (did you
# 	zip warning: remember to use binary mode when you transferred it?)
# 	zip warning: (if you are trying to read a damaged archive try -F)
#
# zip error: Zip file structure invalid (/content/gdrive/MyDrive/datasets/smplpix_data_test.zip)

# %% [markdown]
# ### Install the SMPLpix framework:

# %%
# !git clone https://github.com/sergeyprokudin/smplpix
# %cd /content/smplpix
# !python setup.py install

# %% [markdown]
# ##To train the model on the provided demo dataset, simply run:

# %%
# !pip uninstall torchvision
# !pip3 install torchvision

# %%
# !python /content/smplpix/smplpix/train.py\
        --workdir='/content/smplpix_logs/' \
        --resume_training=0 \
        --data_dir='/content/smplpix_data' \
        --downsample_factor=4 \
        --n_epochs=200 \
        --sched_patience=2 \
        --eval_every_nth_epoch=10 \
        --batch_size=4 \
        --learning_rate=1.0e-3 \
        --n_unet_blocks=5 \
        --aug_prob=0.0
# Out:
# ******************************************************************************************
# ****************************** SMPLpix Training Loop  ************************************
# ******************************************************************************************
# ******** Copyright (c) 2021 - now, Sergey Prokudin (sergey.prokudin@gmail.com) ***********
# ****************************************************************************************+*
#
#
# ARGUMENTS:
# Namespace(aug_prob=0.0, batch_size=4, checkpoint_path=None, data_dir='/content/smplpix_data', data_url=None, device='cuda', downsample_factor=4, eval_every_nth_epoch=10, learning_rate=0.001, n_epochs=200, n_input_channels=3, n_output_channels=3, n_unet_blocks=5, resume_training=0, save_target=1, sched_patience=2, sigmoid_output=True, workdir='/content/smplpix_logs/')
# defining the neural renderer model (U-Net)...
# starting training from scratch, cleaning the log dirs...
# starting training...
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100% 528M/528M [00:01<00:00, 400MB/s]
#   0% 0/200 [00:00<?, ?it/s]
# current epoch: 0
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0000
#   5% 10/200 [00:00<00:16, 11.42it/s]
# current epoch: 10
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0010
#  10% 20/200 [00:01<00:17, 10.19it/s]
# current epoch: 20
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0020
# Epoch 00003: reducing learning rate of group 0 to 1.0000e-04.
#  15% 30/200 [00:04<00:28,  5.91it/s]
# current epoch: 30
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0030
#  20% 39/200 [00:06<00:24,  6.46it/s]
# current epoch: 40
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0040
#  24% 49/200 [00:07<00:14, 10.36it/s]
# current epoch: 50
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0050
# Epoch 00006: reducing learning rate of group 0 to 1.0000e-05.
#  30% 59/200 [00:08<00:12, 11.32it/s]
# current epoch: 60
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0060
#  35% 70/200 [00:11<00:23,  5.57it/s]
# current epoch: 70
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0070
#  40% 80/200 [00:12<00:12,  9.85it/s]
# current epoch: 80
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0080
# Epoch 00009: reducing learning rate of group 0 to 1.0000e-06.
#  45% 90/200 [00:13<00:09, 11.25it/s]
# current epoch: 90
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0090
#  50% 100/200 [00:14<00:08, 11.63it/s]
# current epoch: 100
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0100
#  55% 110/200 [00:15<00:07, 11.63it/s]
# current epoch: 110
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0110
# Epoch 00012: reducing learning rate of group 0 to 1.0000e-07.
#  60% 120/200 [00:19<00:41,  1.92it/s]
# current epoch: 120
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0120
#  65% 130/200 [00:19<00:11,  6.26it/s]
# current epoch: 130
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0130
#  70% 140/200 [00:20<00:05, 10.12it/s]
# current epoch: 140
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0140
# Epoch 00015: reducing learning rate of group 0 to 1.0000e-08.
#  75% 150/200 [00:23<00:12,  3.85it/s]
# current epoch: 150
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0150
#  80% 160/200 [00:24<00:04,  8.66it/s]
# current epoch: 160
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0160
#  85% 170/200 [00:25<00:02, 10.90it/s]
# current epoch: 170
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0170
#  90% 180/200 [00:28<00:05,  3.75it/s]
# current epoch: 180
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0180
#  95% 190/200 [00:29<00:01,  8.57it/s]
# current epoch: 190
# mean VGG loss: nan
# images saved at /content/smplpix_logs/logs/val_preds_0190
# 100% 200/200 [00:30<00:00,  6.51it/s]
# rendering SMPLpix predictions for /content/smplpix_data/train...
# 0it [00:00, ?it/s]
# mean VGG loss: nan
# images saved at /content/smplpix_logs/renders_train
# generating video animation for data /content/smplpix_data/train...
# Traceback (most recent call last):
#   File "/content/smplpix/smplpix/train.py", line 129, in <module>
#     main()
#   File "/content/smplpix/smplpix/train.py", line 122, in main
#     generate_eval_video(args, train_dir, unet, save_target=True)
#   File "/content/smplpix/smplpix/train.py", line 37, in generate_eval_video
#     _ = generate_mp4(final_renders_path, video_animation_path, frame_rate=frame_rate)
#   File "/usr/local/lib/python3.8/dist-packages/smplpix-1.0-py3.8.egg/smplpix/utils.py", line 46, in generate_mp4
#     test_img = os.listdir(image_dir)[0]
# IndexError: list index out of range
